# %% [markdown]
# ### plotting pie charts
# matplotlib.pyplot.pie(x_data, labels, colors, startangle, counterclock, wedgeprops)
# matplotlib.pyplot.axis()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pokemon = pd.read_csv('pokemon.csv')

# %%
sorted_counts = pokemon['generation_id'].value_counts()

plt.pie(sorted_counts, labels=sorted_counts.index, startangle=90, counterclock=False);

# We have the option 'Square'.
#though you can use either one specified here: https://matplotlib.org/api/_as_gen/matplotlib.pyplot.axis.html?highlight=pyplot%20axis#matplotlib-pyplot-axis
plt.axis('square');

# %%
sorted_counts
# Out:
# 5    156
# 1    151
# 3    135
# 4    107
# 2    100
# 7     86
# 6     72
# Name: generation_id, dtype: int64

# %% [markdown]
# ### plotting donut charts
#
# plotting donut plots is as simple as adding the wedgeplots arg to plt.pie().
# setting wedgeprops = {'width': <1} will result in a donut plot

# %%
sorted_counts = pokemon['generation_id'].value_counts()

plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90,
        counterclock = False, wedgeprops = {'width' : 0.4});
plt.axis('square');

# %%
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90,
        counterclock = False, wedgeprops = {'width' : 0.7});
plt.axis('square');
